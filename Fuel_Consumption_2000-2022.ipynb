# %%
import pandas as pd

# %%
df=pd.read_csv("Fuel_Consumption_2000-2022.csv")

# %%
df
# Out:
#        YEAR   MAKE        MODEL  VEHICLE CLASS  ENGINE SIZE  CYLINDERS  \
# 0      2000  ACURA        1.6EL        COMPACT          1.6          4
# 1      2000  ACURA        1.6EL        COMPACT          1.6          4
# 2      2000  ACURA        3.2TL       MID-SIZE          3.2          6
# 3      2000  ACURA        3.5RL       MID-SIZE          3.5          6
# 4      2000  ACURA      INTEGRA     SUBCOMPACT          1.8          4
# ...     ...    ...          ...            ...          ...        ...
# 22551  2022  Volvo  XC40 T5 AWD     SUV: Small          2.0          4
# 22552  2022  Volvo  XC60 B5 AWD     SUV: Small          2.0          4
# 22553  2022  Volvo  XC60 B6 AWD     SUV: Small          2.0          4
# 22554  2022  Volvo  XC90 T5 AWD  SUV: Standard          2.0          4
# 22555  2022  Volvo  XC90 T6 AWD  SUV: Standard          2.0          4
#
#       TRANSMISSION FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  \
# ...

# %%
df2=df[['ENGINE SIZE','CYLINDERS','FUEL CONSUMPTION','EMISSIONS']]
df2
# Out:
#        ENGINE SIZE  CYLINDERS  FUEL CONSUMPTION  EMISSIONS
# 0              1.6          4               9.2        186
# 1              1.6          4               8.5        175
# 2              3.2          6              12.2        230
# 3              3.5          6              13.4        264
# 4              1.8          4              10.0        198
# ...            ...        ...               ...        ...
# 22551          2.0          4              10.7        219
# 22552          2.0          4              10.5        219
# 22553          2.0          4              11.0        232
# 22554          2.0          4              11.5        236
# 22555          2.0          4              12.4        252
#
# [22556 rows x 4 columns]

# %%
df1=df.iloc[:,7:12]
df1
# Out:
#       FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  COMB (mpg)
# 0        X               9.2             6.7              8.1          35
# 1        X               8.5             6.5              7.6          37
# 2        Z              12.2             7.4             10.0          28
# 3        Z              13.4             9.2             11.5          25
# 4        X              10.0             7.0              8.6          33
# ...    ...               ...             ...              ...         ...
# 22551    Z              10.7             7.7              9.4          30
# 22552    Z              10.5             8.1              9.4          30
# 22553    Z              11.0             8.7              9.9          29
# 22554    Z              11.5             8.4             10.1          28
# 22555    Z              12.4             8.9             10.8          26
#
# [22556 rows x 5 columns]

# %%
df2=df1.fillna(20)
df2.head()
# Out:
#   FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  COMB (mpg)
# 0    X               9.2             6.7              8.1          35
# 1    X               8.5             6.5              7.6          37
# 2    Z              12.2             7.4             10.0          28
# 3    Z              13.4             9.2             11.5          25
# 4    X              10.0             7.0              8.6          33

# %%
df3=df1.fillna(df1.max())
df3.head()
# Out:
#   FUEL  FUEL CONSUMPTION  HWY (L/100 km)  COMB (L/100 km)  COMB (mpg)
# 0    X               9.2             6.7              8.1          35
# 1    X               8.5             6.5              7.6          37
# 2    Z              12.2             7.4             10.0          28
# 3    Z              13.4             9.2             11.5          25
# 4    X              10.0             7.0              8.6          33

# %%
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
viz = df3[['FUEL CONSUMPTION','HWY (L/100 km)','COMB (L/100 km)','COMB (mpg)']]
viz.hist()
plt.show()

# %%
plt.scatter(df3.HWY (L/100 km), df3.COMB (L/100 km), color='Blue')
plt.xlabel("HWY (L/100 km)")
plt.ylabel("COMB (L/100 km)")
plt.show()
# Out:
#   Cell In[23], line 1
#     plt.scatter(df3.HWY (L/100 km), df3.COMB (L/100 km), color='Blue')
#                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
from sklearn import linear_model

# %%
msk = np.random.rand(len(df3)) < 0.8
train = df3[msk]
test = df3 [~msk]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 msk = np.random.rand(len(df3)) < 0.8
#       2 train = df3[msk]
#       3 test = df3 [~msk]
#
# NameError: name 'np' is not defined
